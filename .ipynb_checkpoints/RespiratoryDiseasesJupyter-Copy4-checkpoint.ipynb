# %% [markdown]
# **Predicting Respiratory Diseases by the Patient’s Breathing Sounds**
#
# Kaarel Tamuri<br>
# Stina-Marie Maripuu
#
# Set within the healthcare industry, this project focuses on supporting the diagnostic process for respiratory diseases. It aims to harness the potential of machine learning to analyze breathing sounds, to help cure patients more effectively and reliably.
#
# We are using CNN (Convolutional Neural Network), which is a network architecture for deep learning that learns directly from data

# %%
#LIBARIES
# !pip3 install resampy

# %%
#IMPORTS
import os
import pandas as pd
import numpy as np
import librosa
import matplotlib.pyplot as plt
import random
from tqdm import tqdm
import resampy


from imblearn.over_sampling import SMOTE

from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report, roc_curve, auc

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Conv2D, MaxPooling2D, GlobalAveragePooling2D
from tensorflow.keras import metrics
from tensorflow.keras.callbacks import EarlyStopping


from keras.utils import to_categorical


from datetime import datetime
import seaborn as sns

# %%
#All PATHS TO DATA
path_files = "archive/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/"
path_diagnose = "archive/Respiratory_Sound_Database/Respiratory_Sound_Database/patient_diagnosis.csv"

# %%
#.wav filenames
wav_files = []
for file in os.listdir(path_files):
    if file.endswith(".wav"):
        wav_files.append(file)


#patient_diagnosis.csv
diagnose = pd.read_csv(path_diagnose, header=None)

# %%
#Get all file paths
filepaths = []
for i in wav_files:
    path = path_files+i
    filepaths.append(path)


#Find diagnose for every file

file_patient =[]
for i in wav_files:
    pn = int (i[:3])
    file_patient.append(pn)

file_patient = np.array(file_patient)

labels = []
for i in file_patient:
    row = diagnose[diagnose[0] == i]
    labels.append(row[1].values[0])
labels = np.array(labels)

#Remove LTRI and Asthma because there are too few instances
filtered_data = [(fp, pn, label) for fp, pn, label in zip(filepaths, file_patient, labels) if label not in ["LRTI", "Asthma"]]
filepaths, file_patient, labels = zip(*filtered_data)

filepaths = list(filepaths)
file_patient = np.array(file_patient)
labels = np.array(labels)

# %%
unique_elements, counts_elements = np.unique(labels, return_counts=True)

plt.figure(figsize=(10, 6))
bars = plt.bar(unique_elements, counts_elements, color='skyblue')

# Adding the count labels on top of the bars
for bar in bars:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, yval, int(yval), va='bottom', ha='center')

plt.xlabel('Illness')
plt.ylabel('Count')
plt.title('Count of Each Illness Based On Audio Files Before Data Balancing')
plt.xticks(rotation=45)
plt.show()

# %%
def add_noise(data, noise_level=0.01):
    noise = np.random.randn(len(data))
    return data + noise_level * noise

def time_shift(data, sampling_rate, shift_max=0.2):
    shift_amount = int(sampling_rate * shift_max)
    shift = np.random.randint(-shift_amount, shift_amount)
    return np.roll(data, shift)

def change_pitch(audio, sample_rate, n_steps=2.0, bins_per_octave=12, res_type='soxr_hq', scale=False):
    return librosa.effects.pitch_shift(y=audio, sr=sample_rate, n_steps=n_steps, 
                                       bins_per_octave=bins_per_octave, res_type=res_type, scale=scale)

def change_speed(audio, speed_factor=1.2):
    return librosa.effects.time_stretch(y=audio, rate=speed_factor)



def data_augmentation(file_path):
    audio, sample_rate = librosa.load(file_path, res_type='kaiser_fast')
    augmented_audio = [
        add_noise(audio),
        time_shift(audio, sample_rate),
        change_pitch(audio, sample_rate),
        change_speed(audio),
    ]
    return augmented_audio, sample_rate

# %%
def audioLen(file_path):
    audio, sample_rate = librosa.load(file_path, sr=None)
    duration = len(audio) / sample_rate
    return duration

durations = []
for i in filepaths:
    durations.append(audioLen(i))
    

max_dur = max(durations)
min_dur = min(durations)
mean_dur = np.mean(durations)
median_dur = np.median(durations)
percentile_90 = np.percentile(durations, 90)

# Print the results
print(f"Maximum: {max_dur}")
print(f"Minimum: {min_dur}")
print(f"Mean: {mean_dur}")
print(f"Median: {median_dur}")
print(f"90th Percentile: {percentile_90}")

plt.hist(durations, bins='auto', color='blue', alpha=0.7, rwidth=0.85)
plt.title('Audiofile Durations')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.grid(axis='y', alpha=0.75)

# Display the histogram
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[22], line 8
#       6 durations = []
#       7 for i in filepaths:
# ----> 8     durations.append(audioLen(i))
#      11 max_dur = max(durations)
#      12 min_dur = min(durations)
#
# Cell In[22], line 2, in audioLen(file_path)
#       1 def audioLen(file_path):
# ----> 2     audio, sample_rate = librosa.load(file_path, sr=None)
#       3     duration = len(audio) / sample_rate
#       4     return duration
#
# File ~\AppData\Local\anaconda3\envs\IDS\lib\site-packages\librosa\core\audio.py:175, in load(path, sr, mono, offset, duration, dtype, res_type)
#     172 else:
#     173     # Otherwise try soundfile first, and then fall back if necessary
#     174     try:
# --> 175         y, sr_native = __soundfile_load(path, offset, duration, dtype)
#     177     except sf.SoundFileRuntimeError as exc:
#     178         # If soundfile failed, try audioread instead
#     179         if isinstance(path, (str, pathlib.PurePath)):
#
# File ~\AppData\Local\anaconda3\envs\IDS\lib\site-packages\librosa\core\audio.py:221, in __soundfile_load(path, offset, duration, dtype)
#     218         frame_duration = -1
#     220     # Load the target number of frames, and transpose to match librosa form
# --> 221     y = sf_desc.read(frames=frame_duration, dtype=dtype, always_2d=False).T
#     223 return y, sr_native
#
# File ~\AppData\Local\anaconda3\envs\IDS\lib\site-packages\soundfile.py:895, in SoundFile.read(self, frames, dtype, always_2d, fill_value, out)
#     893     if frames < 0 or frames > len(out):
#     894         frames = len(out)
# --> 895 frames = self._array_io('read', out, frames)
#     896 if len(out) > frames:
#     897     if fill_value is None:
#
# File ~\AppData\Local\anaconda3\envs\IDS\lib\site-packages\soundfile.py:1344, in SoundFile._array_io(self, action, array, frames)
#    1342 assert array.dtype.itemsize == _ffi.sizeof(ctype)
#    1343 cdata = _ffi.cast(ctype + '*', array.__array_interface__['data'][0])
# -> 1344 return self._cdata_io(action, cdata, ctype, frames)
#
# File ~\AppData\Local\anaconda3\envs\IDS\lib\site-packages\soundfile.py:1353, in SoundFile._cdata_io(self, action, data, ctype, frames)
#    1351     curr = self.tell()
#    1352 func = getattr(_snd, 'sf_' + action + 'f_' + ctype)
# -> 1353 frames = func(self._file, data, frames)
#    1354 _error_check(self._errorcode)
#    1355 if self.seekable():
#
# KeyboardInterrupt:

# %%
#I take 90th Percentile to cover as much as possible, but to not be as slow
durLen = 20
paddingLen = int(np.ceil(durLen*22050/512))


def extract(file_path):
    try:
        audio, sample_rate = librosa.load(file_path, res_type='kaiser_fast', duration=durLen) 
        mfccs = librosa.feature.mfcc(y=audio, sr=sample_rate, n_mfcc=40)
        pad_width = paddingLen - mfccs.shape[1]
        mfccs = np.pad(mfccs, pad_width=((0, 0), (0, pad_width)), mode='constant')

    except Exception as e:
        print(file_path, e)
        return None 

    return mfccs


def extract_features_from_augmented_audio(file_path):
    augmented_audios, sample_rate = data_augmentation(file_path)
    augmented_features = []  # Initialize an empty list to store features
    for aug_audio in augmented_audios:
        mfccs = librosa.feature.mfcc(y=aug_audio, sr=sample_rate, n_mfcc=40)
        pad_width = paddingLen - mfccs.shape[1]
        mfccs = np.pad(mfccs, pad_width=((0, 0), (0, pad_width)), mode='constant')
        augmented_features.append(mfccs)
    return augmented_features

# %%
X_train, X_test, y_train, y_test = train_test_split(filepaths, labels, test_size=0.3, random_state=1)

# %%
augmented_features_train = []
augmented_labels_train = []

# Process and augment training data
for file_path, label in tqdm(zip(X_train, y_train), total=len(X_train), desc="Processing and augmenting training files"):
    # Extract features for original audio
    mfccs = extract(file_path)
    augmented_features_train.append(mfccs)
    augmented_labels_train.append(label)

    # Augment data
    if label not in ["COPD", "LRTI", "Asthma"]:
        augmented_audios, sample_rate = data_augmentation(file_path)
        for aug_audio in augmented_audios:
            mfccs = librosa.feature.mfcc(y=aug_audio, sr=sample_rate, n_mfcc=40)
            pad_width = paddingLen - mfccs.shape[1]
            mfccs_padded = np.pad(mfccs, pad_width=((0, 0), (0, pad_width)), mode='constant')
            augmented_features_train.append(mfccs_padded)
            augmented_labels_train.append(label)

# Convert training data to numpy arrays
features_train = np.array(augmented_features_train)
labels_train = np.array(augmented_labels_train)

# Process test data (no augmentation)
features_test = []
for fp in tqdm(X_test, desc="Processing test files", total=len(X_test)):
    features_test.append(extract(fp))
features_test = np.array(features_test)

labels_test = np.array(y_test)
# Out:
# Processing and augmenting training files: 100%|██████████████████████████████████████| 641/641 [04:16<00:00,  2.50it/s]
# Processing test files: 100%|█████████████████████████████████████████████████████████| 276/276 [01:17<00:00,  3.56it/s]

# %%
# # features per ilness
unique_elements, counts_elements = np.unique(labels_train, return_counts=True)

print("-----Train-----")
for i in range(len(unique_elements)):
    print("Ilness: "+unique_elements[i]+"; Count: "+str(counts_elements[i]))

unique_elements, counts_elements = np.unique(labels_test, return_counts=True)

print("-----Test-----")
for i in range(len(unique_elements)):
    print("Ilness: "+unique_elements[i]+"; Count: "+str(counts_elements[i]))
# Out:
# -----Train-----
# Ilness: Bronchiectasis; Count: 30
# Ilness: Bronchiolitis; Count: 30
# Ilness: COPD; Count: 564
# Ilness: Healthy; Count: 105
# Ilness: Pneumonia; Count: 140
# Ilness: URTI; Count: 80
# -----Test-----
# Ilness: Bronchiectasis; Count: 10
# Ilness: Bronchiolitis; Count: 7
# Ilness: COPD; Count: 229
# Ilness: Healthy; Count: 14
# Ilness: Pneumonia; Count: 9
# Ilness: URTI; Count: 7

# %%
# Encoding Labels
le = LabelEncoder()
labels_train_encoded = le.fit_transform(labels_train)
labels_train_categorical = to_categorical(labels_train_encoded)

# Reshaping features for CNN input
features_train_reshaped = np.reshape(features_train, (*features_train.shape, 1))

# Apply SMOTE on Training Data
smote = SMOTE()
X_train_smote, y_train_smote = smote.fit_resample(features_train_reshaped.reshape(features_train_reshaped.shape[0], -1), labels_train_categorical)
X_train_smote = X_train_smote.reshape(X_train_smote.shape[0], features_train.shape[1], features_train.shape[2], 1)

# Process Test Data for Model Evaluation (No Augmentation or SMOTE)
labels_test_encoded = le.transform(labels_test)
labels_test_categorical = to_categorical(labels_test_encoded)
features_test_reshaped = np.reshape(features_test, (*features_test.shape, 1))

# %%
# Convert one-hot encoded labels back to label encoding
y_train_smote_labels = np.argmax(y_train_smote, axis=1)

# Count the occurrences of each class
unique_classes, counts_classes = np.unique(y_train_smote_labels, return_counts=True)

# Map the integer labels back to the original class names
class_names = le.inverse_transform(unique_classes)

plt.figure(figsize=(10, 6))
bars = plt.bar(class_names, counts_classes, color='skyblue')

# Adding count labels on top of the bars
for bar in bars:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, yval, int(yval), va='bottom', ha='center')

plt.xlabel('Illness')
plt.ylabel('Count')
plt.title('Count of Each Illness Based On Audio Files After Data Balancing')
plt.xticks(rotation=45)
plt.show()

# %%
rows = 40 #MFCC number
columns = paddingLen #frames
channels = 1

num_labels = labels_train_categorical.shape[1]
filter_size = 2

model = Sequential()
model.add(Conv2D(filters=16, kernel_size=filter_size,
                 input_shape=(rows, columns, channels), activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.2))

model.add(Conv2D(filters=32, kernel_size=filter_size, activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.2))

model.add(Conv2D(filters=64, kernel_size=filter_size, activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.2))

model.add(Conv2D(filters=128, kernel_size=filter_size, activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.2))

model.add(GlobalAveragePooling2D())

model.add(Dense(num_labels, activation='softmax'))

# %%
model.compile(loss='categorical_crossentropy', metrics=['accuracy', metrics.Recall()], optimizer='adam')

# %%
# train model
num_epochs = 200
num_batch_size = 128


# Ensure that validation data is the reshaped and encoded test data
model.fit(X_train_smote, y_train_smote, batch_size=num_batch_size, epochs=num_epochs,
          validation_data=(features_test_reshaped, labels_test_categorical), verbose=1)
# Out:
# Epoch 1/200
# 27/27 [==============================] - 18s 678ms/step - loss: 0.5346 - accuracy: 0.7940 - recall_1: 0.7397 - val_loss: 0.5836 - val_accuracy: 0.8225 - val_recall_1: 0.7717
# Epoch 2/200
# 27/27 [==============================] - 17s 616ms/step - loss: 0.5186 - accuracy: 0.8047 - recall_1: 0.7518 - val_loss: 0.5466 - val_accuracy: 0.8478 - val_recall_1: 0.7935
# Epoch 3/200
# 27/27 [==============================] - 17s 628ms/step - loss: 0.4870 - accuracy: 0.8177 - recall_1: 0.7544 - val_loss: 0.5299 - val_accuracy: 0.8333 - val_recall_1: 0.8080
# Epoch 4/200
# 27/27 [==============================] - 17s 612ms/step - loss: 0.4665 - accuracy: 0.8262 - recall_1: 0.7633 - val_loss: 0.8435 - val_accuracy: 0.6993 - val_recall_1: 0.6486
# Epoch 5/200
# 27/27 [==============================] - 17s 618ms/step - loss: 0.4497 - accuracy: 0.8257 - recall_1: 0.7757 - val_loss: 0.8323 - val_accuracy: 0.7210 - val_recall_1: 0.6739
# Epoch 6/200
# 27/27 [==============================] - 17s 613ms/step - loss: 0.4423 - accuracy: 0.8268 - recall_1: 0.7866 - val_loss: 0.5921 - val_accuracy: 0.8225 - val_recall_1: 0.7899
# Epoch 7/200
# 27/27 [==============================] - 17s 614ms/step - loss: 0.4218 - accuracy: 0.8413 - recall_1: 0.7988 - val_loss: 0.5526 - val_accuracy: 0.8406 - val_recall_1: 0.8261
# Epoch 8/200
# 27/27 [==============================] - 17s 612ms/step - loss: 0.4443 - accuracy: 0.8298 - recall_1: 0.7881 - val_loss: 0.6044 - val_accuracy: 0.8225 - val_recall_1: 0.7935
# Epoch 9/200
# 27/27 [==============================] - 17s 611ms/step - loss: 0.3879 - accuracy: 0.8484 - recall_1: 0.8070 - val_loss: 0.6496 - val_accuracy: 0.8152 - val_recall_1: 0.8007
# Epoch 10/200
# 27/27 [==============================] - 17s 611ms/step - loss: 0.3917 - accuracy: 0.8469 - recall_1: 0.8053 - val_loss: 0.6094 - val_accuracy: 0.8333 - val_recall_1: 0.8080
# Epoch 11/200
# 27/27 [==============================] - 17s 615ms/step - loss: 0.3950 - accuracy: 0.8389 - recall_1: 0.8059 - val_loss: 0.5662 - val_accuracy: 0.8406 - val_recall_1: 0.8333
# Epoch 12/200
# 27/27 [==============================] - 17s 621ms/step - loss: 0.3510 - accuracy: 0.8720 - recall_1: 0.8366 - val_loss: 0.6156 - val_accuracy: 0.8333 - val_recall_1: 0.8152
# Epoch 13/200
# 27/27 [==============================] - 18s 654ms/step - loss: 0.3349 - accuracy: 0.8717 - recall_1: 0.8389 - val_loss: 0.5532 - val_accuracy: 0.8442 - val_recall_1: 0.8370
# Epoch 14/200
# 27/27 [==============================] - 17s 620ms/step - loss: 0.3234 - accuracy: 0.8780 - recall_1: 0.8449 - val_loss: 0.7195 - val_accuracy: 0.8116 - val_recall_1: 0.7899
# Epoch 15/200
# 27/27 [==============================] - 17s 615ms/step - loss: 0.3238 - accuracy: 0.8762 - recall_1: 0.8496 - val_loss: 0.6743 - val_accuracy: 0.8080 - val_recall_1: 0.7754
# Epoch 16/200
# 27/27 [==============================] - 17s 617ms/step - loss: 0.3089 - accuracy: 0.8842 - recall_1: 0.8576 - val_loss: 0.5474 - val_accuracy: 0.8551 - val_recall_1: 0.8478
# Epoch 17/200
# 27/27 [==============================] - 17s 615ms/step - loss: 0.3067 - accuracy: 0.8898 - recall_1: 0.8605 - val_loss: 0.6580 - val_accuracy: 0.8514 - val_recall_1: 0.8333
# Epoch 18/200
# 27/27 [==============================] - 17s 616ms/step - loss: 0.3048 - accuracy: 0.8821 - recall_1: 0.8525 - val_loss: 0.6226 - val_accuracy: 0.8514 - val_recall_1: 0.8333
# Epoch 19/200
# 27/27 [==============================] - 17s 613ms/step - loss: 0.2929 - accuracy: 0.8830 - recall_1: 0.8620 - val_loss: 0.5958 - val_accuracy: 0.8659 - val_recall_1: 0.8406
# Epoch 20/200
# 27/27 [==============================] - 17s 617ms/step - loss: 0.2721 - accuracy: 0.9022 - recall_1: 0.8794 - val_loss: 0.7345 - val_accuracy: 0.8116 - val_recall_1: 0.7862
# Epoch 21/200
# 27/27 [==============================] - 17s 613ms/step - loss: 0.2775 - accuracy: 0.8960 - recall_1: 0.8741 - val_loss: 0.8715 - val_accuracy: 0.7862 - val_recall_1: 0.7862
# Epoch 22/200
# 27/27 [==============================] - 17s 614ms/step - loss: 0.2698 - accuracy: 0.9019 - recall_1: 0.8788 - val_loss: 0.7160 - val_accuracy: 0.8188 - val_recall_1: 0.8007
# Epoch 23/200
# 27/27 [==============================] - 17s 624ms/step - loss: 0.2368 - accuracy: 0.9116 - recall_1: 0.8951 - val_loss: 0.8260 - val_accuracy: 0.8007 - val_recall_1: 0.7935
# Epoch 24/200
# 27/27 [==============================] - 17s 615ms/step - loss: 0.2561 - accuracy: 0.9007 - recall_1: 0.8833 - val_loss: 0.6747 - val_accuracy: 0.8551 - val_recall_1: 0.8442
# Epoch 25/200
# 27/27 [==============================] - 18s 658ms/step - loss: 0.2461 - accuracy: 0.9125 - recall_1: 0.8980 - val_loss: 0.6901 - val_accuracy: 0.8732 - val_recall_1: 0.8514
# Epoch 26/200
# 27/27 [==============================] - 17s 616ms/step - loss: 0.2372 - accuracy: 0.9099 - recall_1: 0.8945 - val_loss: 0.8399 - val_accuracy: 0.7971 - val_recall_1: 0.7935
# Epoch 27/200
# 27/27 [==============================] - 17s 617ms/step - loss: 0.2236 - accuracy: 0.9146 - recall_1: 0.8975 - val_loss: 0.7988 - val_accuracy: 0.8188 - val_recall_1: 0.8080
# Epoch 28/200
# 27/27 [==============================] - 17s 620ms/step - loss: 0.2226 - accuracy: 0.9128 - recall_1: 0.8989 - val_loss: 0.8531 - val_accuracy: 0.8043 - val_recall_1: 0.7935
# Epoch 29/200
# 27/27 [==============================] - 17s 626ms/step - loss: 0.2219 - accuracy: 0.9178 - recall_1: 0.9028 - val_loss: 0.6781 - val_accuracy: 0.8587 - val_recall_1: 0.8514
# Epoch 30/200
# 27/27 [==============================] - 18s 655ms/step - loss: 0.2297 - accuracy: 0.9170 - recall_1: 0.9013 - val_loss: 0.6854 - val_accuracy: 0.8659 - val_recall_1: 0.8587
# Epoch 31/200
# 27/27 [==============================] - 18s 661ms/step - loss: 0.2065 - accuracy: 0.9249 - recall_1: 0.9096 - val_loss: 0.9412 - val_accuracy: 0.8152 - val_recall_1: 0.8080
# Epoch 32/200
# 27/27 [==============================] - 19s 696ms/step - loss: 0.2258 - accuracy: 0.9229 - recall_1: 0.9096 - val_loss: 0.7593 - val_accuracy: 0.8478 - val_recall_1: 0.8333
# Epoch 33/200
# 27/27 [==============================] - 17s 618ms/step - loss: 0.2016 - accuracy: 0.9270 - recall_1: 0.9155 - val_loss: 0.7500 - val_accuracy: 0.8478 - val_recall_1: 0.8442
# Epoch 34/200
# 27/27 [==============================] - 18s 653ms/step - loss: 0.1927 - accuracy: 0.9249 - recall_1: 0.9131 - val_loss: 0.7370 - val_accuracy: 0.8623 - val_recall_1: 0.8551
# Epoch 35/200
# 27/27 [==============================] - 17s 631ms/step - loss: 0.1913 - accuracy: 0.9276 - recall_1: 0.9176 - val_loss: 0.8135 - val_accuracy: 0.8225 - val_recall_1: 0.8043
# Epoch 36/200
# 27/27 [==============================] - 17s 614ms/step - loss: 0.1923 - accuracy: 0.9291 - recall_1: 0.9178 - val_loss: 0.6901 - val_accuracy: 0.8659 - val_recall_1: 0.8623
# Epoch 37/200
# 27/27 [==============================] - 17s 619ms/step - loss: 0.1816 - accuracy: 0.9306 - recall_1: 0.9205 - val_loss: 0.8517 - val_accuracy: 0.8297 - val_recall_1: 0.8261
# Epoch 38/200
# 27/27 [==============================] - 17s 616ms/step - loss: 0.1664 - accuracy: 0.9379 - recall_1: 0.9279 - val_loss: 0.9083 - val_accuracy: 0.8152 - val_recall_1: 0.8043
# Epoch 39/200
# 27/27 [==============================] - 17s 614ms/step - loss: 0.1943 - accuracy: 0.9235 - recall_1: 0.9152 - val_loss: 0.7347 - val_accuracy: 0.8659 - val_recall_1: 0.8623
# Epoch 40/200
# 27/27 [==============================] - 17s 612ms/step - loss: 0.1882 - accuracy: 0.9258 - recall_1: 0.9193 - val_loss: 0.7710 - val_accuracy: 0.8659 - val_recall_1: 0.8623
# Epoch 41/200
# 27/27 [==============================] - 17s 621ms/step - loss: 0.1896 - accuracy: 0.9270 - recall_1: 0.9181 - val_loss: 1.0440 - val_accuracy: 0.7645 - val_recall_1: 0.7645
# Epoch 42/200
# 27/27 [==============================] - 17s 616ms/step - loss: 0.1909 - accuracy: 0.9252 - recall_1: 0.9170 - val_loss: 0.7643 - val_accuracy: 0.8659 - val_recall_1: 0.8587
# Epoch 43/200
# 27/27 [==============================] - 17s 617ms/step - loss: 0.1791 - accuracy: 0.9350 - recall_1: 0.9238 - val_loss: 0.7649 - val_accuracy: 0.8768 - val_recall_1: 0.8696
# Epoch 44/200
# 27/27 [==============================] - 17s 617ms/step - loss: 0.1676 - accuracy: 0.9400 - recall_1: 0.9320 - val_loss: 0.6963 - val_accuracy: 0.8804 - val_recall_1: 0.8768
# Epoch 45/200
# 27/27 [==============================] - 17s 612ms/step - loss: 0.1422 - accuracy: 0.9512 - recall_1: 0.9385 - val_loss: 0.9217 - val_accuracy: 0.8442 - val_recall_1: 0.8406
# Epoch 46/200
# 27/27 [==============================] - 17s 614ms/step - loss: 0.1398 - accuracy: 0.9462 - recall_1: 0.9379 - val_loss: 0.9642 - val_accuracy: 0.8188 - val_recall_1: 0.8116
# Epoch 47/200
# 27/27 [==============================] - 17s 612ms/step - loss: 0.1576 - accuracy: 0.9415 - recall_1: 0.9332 - val_loss: 0.8450 - val_accuracy: 0.8587 - val_recall_1: 0.8406
# Epoch 48/200
# 27/27 [==============================] - 17s 617ms/step - loss: 0.1378 - accuracy: 0.9515 - recall_1: 0.9406 - val_loss: 0.9023 - val_accuracy: 0.8551 - val_recall_1: 0.8442
# Epoch 49/200
# 27/27 [==============================] - 17s 613ms/step - loss: 0.1358 - accuracy: 0.9486 - recall_1: 0.9421 - val_loss: 0.8681 - val_accuracy: 0.8587 - val_recall_1: 0.8551
# Epoch 50/200
# 27/27 [==============================] - 17s 617ms/step - loss: 0.1437 - accuracy: 0.9495 - recall_1: 0.9424 - val_loss: 0.9124 - val_accuracy: 0.8587 - val_recall_1: 0.8514
# Epoch 51/200
# 27/27 [==============================] - 17s 613ms/step - loss: 0.1400 - accuracy: 0.9498 - recall_1: 0.9412 - val_loss: 0.8960 - val_accuracy: 0.8659 - val_recall_1: 0.8442
# Epoch 52/200
# 27/27 [==============================] - 17s 612ms/step - loss: 0.1305 - accuracy: 0.9504 - recall_1: 0.9439 - val_loss: 0.8437 - val_accuracy: 0.8804 - val_recall_1: 0.8732
# Epoch 53/200
# 27/27 [==============================] - 17s 613ms/step - loss: 0.1284 - accuracy: 0.9471 - recall_1: 0.9403 - val_loss: 1.0373 - val_accuracy: 0.8442 - val_recall_1: 0.8406
# Epoch 54/200
# 27/27 [==============================] - 17s 614ms/step - loss: 0.1312 - accuracy: 0.9545 - recall_1: 0.9456 - val_loss: 0.9161 - val_accuracy: 0.8623 - val_recall_1: 0.8587
# Epoch 55/200
# 27/27 [==============================] - 17s 618ms/step - loss: 0.1269 - accuracy: 0.9572 - recall_1: 0.9489 - val_loss: 1.0947 - val_accuracy: 0.8261 - val_recall_1: 0.8225
# Epoch 56/200
# 27/27 [==============================] - 17s 615ms/step - loss: 0.1281 - accuracy: 0.9527 - recall_1: 0.9468 - val_loss: 1.1472 - val_accuracy: 0.8007 - val_recall_1: 0.7971
# Epoch 57/200
# 27/27 [==============================] - 17s 622ms/step - loss: 0.1224 - accuracy: 0.9542 - recall_1: 0.9474 - val_loss: 1.0495 - val_accuracy: 0.8333 - val_recall_1: 0.8297
# Epoch 58/200
# 27/27 [==============================] - 17s 613ms/step - loss: 0.1165 - accuracy: 0.9586 - recall_1: 0.9545 - val_loss: 0.9783 - val_accuracy: 0.8478 - val_recall_1: 0.8442
# Epoch 59/200
# 27/27 [==============================] - 17s 618ms/step - loss: 0.1107 - accuracy: 0.9586 - recall_1: 0.9539 - val_loss: 1.0185 - val_accuracy: 0.8478 - val_recall_1: 0.8442
# Epoch 60/200
# 27/27 [==============================] - 17s 613ms/step - loss: 0.1151 - accuracy: 0.9524 - recall_1: 0.9507 - val_loss: 1.0526 - val_accuracy: 0.8551 - val_recall_1: 0.8478
# Epoch 61/200
# 27/27 [==============================] - 17s 613ms/step - loss: 0.1380 - accuracy: 0.9436 - recall_1: 0.9385 - val_loss: 0.9256 - val_accuracy: 0.8659 - val_recall_1: 0.8587
# Epoch 62/200
# 27/27 [==============================] - 17s 621ms/step - loss: 0.1105 - accuracy: 0.9572 - recall_1: 0.9509 - val_loss: 1.1290 - val_accuracy: 0.8261 - val_recall_1: 0.8188
# Epoch 63/200
# 27/27 [==============================] - 17s 620ms/step - loss: 0.1176 - accuracy: 0.9563 - recall_1: 0.9504 - val_loss: 1.0486 - val_accuracy: 0.8442 - val_recall_1: 0.8442
# Epoch 64/200
# 27/27 [==============================] - 17s 612ms/step - loss: 0.1286 - accuracy: 0.9507 - recall_1: 0.9436 - val_loss: 1.0067 - val_accuracy: 0.8478 - val_recall_1: 0.8478
# Epoch 65/200
# 27/27 [==============================] - 17s 616ms/step - loss: 0.1078 - accuracy: 0.9610 - recall_1: 0.9548 - val_loss: 1.1392 - val_accuracy: 0.8297 - val_recall_1: 0.8297
# Epoch 66/200
# 27/27 [==============================] - 17s 617ms/step - loss: 0.1123 - accuracy: 0.9557 - recall_1: 0.9515 - val_loss: 0.9956 - val_accuracy: 0.8514 - val_recall_1: 0.8478
# Epoch 67/200
# 27/27 [==============================] - 17s 614ms/step - loss: 0.1137 - accuracy: 0.9536 - recall_1: 0.9486 - val_loss: 1.2282 - val_accuracy: 0.8152 - val_recall_1: 0.8080
# Epoch 68/200
# 27/27 [==============================] - 17s 616ms/step - loss: 0.0984 - accuracy: 0.9648 - recall_1: 0.9610 - val_loss: 1.0826 - val_accuracy: 0.8406 - val_recall_1: 0.8406
# Epoch 69/200
# 27/27 [==============================] - 17s 622ms/step - loss: 0.1031 - accuracy: 0.9607 - recall_1: 0.9560 - val_loss: 1.0916 - val_accuracy: 0.8551 - val_recall_1: 0.8478
# Epoch 70/200
# 27/27 [==============================] - 17s 618ms/step - loss: 0.1271 - accuracy: 0.9489 - recall_1: 0.9421 - val_loss: 1.4037 - val_accuracy: 0.7754 - val_recall_1: 0.7754
# Epoch 71/200
# 27/27 [==============================] - 17s 614ms/step - loss: 0.1445 - accuracy: 0.9433 - recall_1: 0.9391 - val_loss: 0.8913 - val_accuracy: 0.8732 - val_recall_1: 0.8696
# Epoch 72/200
# 27/27 [==============================] - 17s 615ms/step - loss: 0.1019 - accuracy: 0.9634 - recall_1: 0.9572 - val_loss: 1.0016 - val_accuracy: 0.8551 - val_recall_1: 0.8478
# Epoch 73/200
# 27/27 [==============================] - 17s 616ms/step - loss: 0.0922 - accuracy: 0.9645 - recall_1: 0.9592 - val_loss: 1.0656 - val_accuracy: 0.8551 - val_recall_1: 0.8442
# Epoch 74/200
# 27/27 [==============================] - 17s 612ms/step - loss: 0.0862 - accuracy: 0.9651 - recall_1: 0.9607 - val_loss: 0.9195 - val_accuracy: 0.8877 - val_recall_1: 0.8841
# Epoch 75/200
# 27/27 [==============================] - 17s 614ms/step - loss: 0.0953 - accuracy: 0.9648 - recall_1: 0.9601 - val_loss: 1.0678 - val_accuracy: 0.8696 - val_recall_1: 0.8623
# Epoch 76/200
# 27/27 [==============================] - 17s 614ms/step - loss: 0.1067 - accuracy: 0.9583 - recall_1: 0.9557 - val_loss: 1.2143 - val_accuracy: 0.8478 - val_recall_1: 0.8406
# Epoch 77/200
# 27/27 [==============================] - 17s 617ms/step - loss: 0.0839 - accuracy: 0.9675 - recall_1: 0.9639 - val_loss: 1.2063 - val_accuracy: 0.8297 - val_recall_1: 0.8261
# Epoch 78/200
# 27/27 [==============================] - 17s 612ms/step - loss: 0.0942 - accuracy: 0.9660 - recall_1: 0.9625 - val_loss: 1.3401 - val_accuracy: 0.8261 - val_recall_1: 0.8225
# Epoch 79/200
# 27/27 [==============================] - 17s 620ms/step - loss: 0.0900 - accuracy: 0.9628 - recall_1: 0.9589 - val_loss: 1.1345 - val_accuracy: 0.8696 - val_recall_1: 0.8623
# Epoch 80/200
# 27/27 [==============================] - 17s 617ms/step - loss: 0.0958 - accuracy: 0.9639 - recall_1: 0.9604 - val_loss: 1.2048 - val_accuracy: 0.8551 - val_recall_1: 0.8478
# Epoch 81/200
# 27/27 [==============================] - 17s 614ms/step - loss: 0.0936 - accuracy: 0.9669 - recall_1: 0.9634 - val_loss: 1.3534 - val_accuracy: 0.8261 - val_recall_1: 0.8225
# Epoch 82/200
# 27/27 [==============================] - 17s 614ms/step - loss: 0.0968 - accuracy: 0.9642 - recall_1: 0.9592 - val_loss: 1.0726 - val_accuracy: 0.8768 - val_recall_1: 0.8768
# Epoch 83/200
# 27/27 [==============================] - 17s 618ms/step - loss: 0.0878 - accuracy: 0.9666 - recall_1: 0.9639 - val_loss: 1.2711 - val_accuracy: 0.8406 - val_recall_1: 0.8370
# Epoch 84/200
# 27/27 [==============================] - 17s 633ms/step - loss: 0.0766 - accuracy: 0.9707 - recall_1: 0.9693 - val_loss: 1.4290 - val_accuracy: 0.8188 - val_recall_1: 0.8152
# Epoch 85/200
# 27/27 [==============================] - 17s 616ms/step - loss: 0.0793 - accuracy: 0.9690 - recall_1: 0.9651 - val_loss: 1.3263 - val_accuracy: 0.8370 - val_recall_1: 0.8297
# Epoch 86/200
# 27/27 [==============================] - 17s 614ms/step - loss: 0.0721 - accuracy: 0.9737 - recall_1: 0.9722 - val_loss: 1.2825 - val_accuracy: 0.8551 - val_recall_1: 0.8551
# Epoch 87/200
# 27/27 [==============================] - 17s 614ms/step - loss: 0.0813 - accuracy: 0.9704 - recall_1: 0.9687 - val_loss: 1.2653 - val_accuracy: 0.8478 - val_recall_1: 0.8442
# Epoch 88/200
# 27/27 [==============================] - 17s 612ms/step - loss: 0.0944 - accuracy: 0.9604 - recall_1: 0.9569 - val_loss: 1.1904 - val_accuracy: 0.8514 - val_recall_1: 0.8514
# Epoch 89/200
# 27/27 [==============================] - 16s 610ms/step - loss: 0.0785 - accuracy: 0.9687 - recall_1: 0.9639 - val_loss: 1.4218 - val_accuracy: 0.8370 - val_recall_1: 0.8333
# Epoch 90/200
# 27/27 [==============================] - 16s 609ms/step - loss: 0.0767 - accuracy: 0.9722 - recall_1: 0.9687 - val_loss: 1.1994 - val_accuracy: 0.8732 - val_recall_1: 0.8696
# Epoch 91/200
# 27/27 [==============================] - 17s 618ms/step - loss: 0.0705 - accuracy: 0.9713 - recall_1: 0.9693 - val_loss: 1.4114 - val_accuracy: 0.8333 - val_recall_1: 0.8333
# Epoch 92/200
# 27/27 [==============================] - 17s 615ms/step - loss: 0.0746 - accuracy: 0.9722 - recall_1: 0.9704 - val_loss: 1.1931 - val_accuracy: 0.8623 - val_recall_1: 0.8587
# Epoch 93/200
# 27/27 [==============================] - 17s 612ms/step - loss: 0.0754 - accuracy: 0.9707 - recall_1: 0.9693 - val_loss: 1.5021 - val_accuracy: 0.8116 - val_recall_1: 0.8116
# Epoch 94/200
# 27/27 [==============================] - 16s 610ms/step - loss: 0.0822 - accuracy: 0.9687 - recall_1: 0.9654 - val_loss: 1.2400 - val_accuracy: 0.8514 - val_recall_1: 0.8478
# Epoch 95/200
# 27/27 [==============================] - 17s 611ms/step - loss: 0.0821 - accuracy: 0.9702 - recall_1: 0.9687 - val_loss: 1.3205 - val_accuracy: 0.8370 - val_recall_1: 0.8370
# Epoch 96/200
# 27/27 [==============================] - 17s 616ms/step - loss: 0.0917 - accuracy: 0.9657 - recall_1: 0.9631 - val_loss: 1.2957 - val_accuracy: 0.8551 - val_recall_1: 0.8551
# Epoch 97/200
# 27/27 [==============================] - 17s 612ms/step - loss: 0.1057 - accuracy: 0.9563 - recall_1: 0.9539 - val_loss: 1.1133 - val_accuracy: 0.8696 - val_recall_1: 0.8696
# Epoch 98/200
# 27/27 [==============================] - 17s 612ms/step - loss: 0.0744 - accuracy: 0.9702 - recall_1: 0.9684 - val_loss: 1.1859 - val_accuracy: 0.8587 - val_recall_1: 0.8514
# Epoch 99/200
# 27/27 [==============================] - 17s 615ms/step - loss: 0.0724 - accuracy: 0.9740 - recall_1: 0.9725 - val_loss: 1.0794 - val_accuracy: 0.8732 - val_recall_1: 0.8732
# Epoch 100/200
# 27/27 [==============================] - 17s 617ms/step - loss: 0.0736 - accuracy: 0.9725 - recall_1: 0.9699 - val_loss: 1.3241 - val_accuracy: 0.8514 - val_recall_1: 0.8406
# Epoch 101/200
# 27/27 [==============================] - 17s 612ms/step - loss: 0.0805 - accuracy: 0.9660 - recall_1: 0.9637 - val_loss: 1.3675 - val_accuracy: 0.8406 - val_recall_1: 0.8333
# Epoch 102/200
# 27/27 [==============================] - 17s 616ms/step - loss: 0.0908 - accuracy: 0.9631 - recall_1: 0.9604 - val_loss: 1.2378 - val_accuracy: 0.8478 - val_recall_1: 0.8442
# Epoch 103/200
# 27/27 [==============================] - 17s 612ms/step - loss: 0.0646 - accuracy: 0.9781 - recall_1: 0.9758 - val_loss: 1.1117 - val_accuracy: 0.8732 - val_recall_1: 0.8696
# Epoch 104/200
# 27/27 [==============================] - 19s 693ms/step - loss: 0.0671 - accuracy: 0.9743 - recall_1: 0.9704 - val_loss: 1.1814 - val_accuracy: 0.8877 - val_recall_1: 0.8841
# Epoch 105/200
# 27/27 [==============================] - 17s 629ms/step - loss: 0.0758 - accuracy: 0.9713 - recall_1: 0.9690 - val_loss: 1.3573 - val_accuracy: 0.8696 - val_recall_1: 0.8696
# Epoch 106/200
# 27/27 [==============================] - 17s 623ms/step - loss: 0.0754 - accuracy: 0.9713 - recall_1: 0.9699 - val_loss: 1.4655 - val_accuracy: 0.8333 - val_recall_1: 0.8333
# Epoch 107/200
# 27/27 [==============================] - 17s 612ms/step - loss: 0.0638 - accuracy: 0.9758 - recall_1: 0.9740 - val_loss: 1.3001 - val_accuracy: 0.8478 - val_recall_1: 0.8478
# Epoch 108/200
# 27/27 [==============================] - 17s 614ms/step - loss: 0.0674 - accuracy: 0.9761 - recall_1: 0.9743 - val_loss: 1.3392 - val_accuracy: 0.8587 - val_recall_1: 0.8587
# Epoch 109/200
# 27/27 [==============================] - 17s 622ms/step - loss: 0.0646 - accuracy: 0.9764 - recall_1: 0.9749 - val_loss: 1.2066 - val_accuracy: 0.8587 - val_recall_1: 0.8587
# Epoch 110/200
# 27/27 [==============================] - 17s 619ms/step - loss: 0.0494 - accuracy: 0.9849 - recall_1: 0.9843 - val_loss: 1.2625 - val_accuracy: 0.8732 - val_recall_1: 0.8732
# Epoch 111/200
# 27/27 [==============================] - 17s 614ms/step - loss: 0.0598 - accuracy: 0.9755 - recall_1: 0.9740 - val_loss: 1.3730 - val_accuracy: 0.8587 - val_recall_1: 0.8551
# Epoch 112/200
# 27/27 [==============================] - 17s 613ms/step - loss: 0.0672 - accuracy: 0.9755 - recall_1: 0.9737 - val_loss: 1.4234 - val_accuracy: 0.8659 - val_recall_1: 0.8659
# Epoch 113/200
# 27/27 [==============================] - 17s 618ms/step - loss: 0.0757 - accuracy: 0.9719 - recall_1: 0.9702 - val_loss: 1.4324 - val_accuracy: 0.8587 - val_recall_1: 0.8551
# Epoch 114/200
# 27/27 [==============================] - 17s 615ms/step - loss: 0.0608 - accuracy: 0.9758 - recall_1: 0.9725 - val_loss: 1.3822 - val_accuracy: 0.8478 - val_recall_1: 0.8478
# Epoch 115/200
# 27/27 [==============================] - 17s 616ms/step - loss: 0.0627 - accuracy: 0.9772 - recall_1: 0.9758 - val_loss: 1.4940 - val_accuracy: 0.8478 - val_recall_1: 0.8478
# Epoch 116/200
# 27/27 [==============================] - 17s 615ms/step - loss: 0.1080 - accuracy: 0.9616 - recall_1: 0.9595 - val_loss: 1.5846 - val_accuracy: 0.8152 - val_recall_1: 0.8152
# Epoch 117/200
# 27/27 [==============================] - 17s 614ms/step - loss: 0.1129 - accuracy: 0.9542 - recall_1: 0.9509 - val_loss: 1.3220 - val_accuracy: 0.8587 - val_recall_1: 0.8587
# Epoch 118/200
# 27/27 [==============================] - 17s 616ms/step - loss: 0.0718 - accuracy: 0.9722 - recall_1: 0.9702 - val_loss: 1.1776 - val_accuracy: 0.8696 - val_recall_1: 0.8696
# Epoch 119/200
# 27/27 [==============================] - 17s 615ms/step - loss: 0.0578 - accuracy: 0.9805 - recall_1: 0.9790 - val_loss: 1.4199 - val_accuracy: 0.8442 - val_recall_1: 0.8442
# Epoch 120/200
# 27/27 [==============================] - 17s 617ms/step - loss: 0.0571 - accuracy: 0.9802 - recall_1: 0.9790 - val_loss: 1.3630 - val_accuracy: 0.8587 - val_recall_1: 0.8587
# Epoch 121/200
# 27/27 [==============================] - 17s 613ms/step - loss: 0.0639 - accuracy: 0.9775 - recall_1: 0.9740 - val_loss: 1.3124 - val_accuracy: 0.8587 - val_recall_1: 0.8587
# Epoch 122/200
# 27/27 [==============================] - 17s 613ms/step - loss: 0.0561 - accuracy: 0.9790 - recall_1: 0.9775 - val_loss: 1.1729 - val_accuracy: 0.8768 - val_recall_1: 0.8768
# Epoch 123/200
# 27/27 [==============================] - 17s 613ms/step - loss: 0.0592 - accuracy: 0.9770 - recall_1: 0.9746 - val_loss: 1.3316 - val_accuracy: 0.8623 - val_recall_1: 0.8623
# Epoch 124/200
# 27/27 [==============================] - 17s 612ms/step - loss: 0.0582 - accuracy: 0.9761 - recall_1: 0.9755 - val_loss: 1.5149 - val_accuracy: 0.8442 - val_recall_1: 0.8406
# Epoch 125/200
# 27/27 [==============================] - 17s 613ms/step - loss: 0.0494 - accuracy: 0.9811 - recall_1: 0.9790 - val_loss: 1.6122 - val_accuracy: 0.8333 - val_recall_1: 0.8333
# Epoch 126/200
# 27/27 [==============================] - 17s 614ms/step - loss: 0.0504 - accuracy: 0.9829 - recall_1: 0.9811 - val_loss: 1.4813 - val_accuracy: 0.8551 - val_recall_1: 0.8551
# Epoch 127/200
# 27/27 [==============================] - 17s 616ms/step - loss: 0.0484 - accuracy: 0.9823 - recall_1: 0.9811 - val_loss: 1.4675 - val_accuracy: 0.8587 - val_recall_1: 0.8587
# Epoch 128/200
# 27/27 [==============================] - 17s 618ms/step - loss: 0.0508 - accuracy: 0.9811 - recall_1: 0.9808 - val_loss: 1.3663 - val_accuracy: 0.8406 - val_recall_1: 0.8406
# Epoch 129/200
# 27/27 [==============================] - 17s 613ms/step - loss: 0.0591 - accuracy: 0.9772 - recall_1: 0.9761 - val_loss: 2.0841 - val_accuracy: 0.7681 - val_recall_1: 0.7645
# Epoch 130/200
# 27/27 [==============================] - 17s 613ms/step - loss: 0.0681 - accuracy: 0.9728 - recall_1: 0.9710 - val_loss: 1.4314 - val_accuracy: 0.8732 - val_recall_1: 0.8732
# Epoch 131/200
# 27/27 [==============================] - 17s 614ms/step - loss: 0.0857 - accuracy: 0.9704 - recall_1: 0.9687 - val_loss: 1.5641 - val_accuracy: 0.8043 - val_recall_1: 0.8043
# Epoch 132/200
# 27/27 [==============================] - 17s 621ms/step - loss: 0.0846 - accuracy: 0.9642 - recall_1: 0.9637 - val_loss: 1.1730 - val_accuracy: 0.8877 - val_recall_1: 0.8877
# Epoch 133/200
# 27/27 [==============================] - 17s 616ms/step - loss: 0.0499 - accuracy: 0.9808 - recall_1: 0.9796 - val_loss: 1.3569 - val_accuracy: 0.8623 - val_recall_1: 0.8623
# Epoch 134/200
# 27/27 [==============================] - 17s 612ms/step - loss: 0.0463 - accuracy: 0.9835 - recall_1: 0.9823 - val_loss: 1.4016 - val_accuracy: 0.8442 - val_recall_1: 0.8442
# Epoch 135/200
# 27/27 [==============================] - 17s 615ms/step - loss: 0.0400 - accuracy: 0.9855 - recall_1: 0.9852 - val_loss: 1.5007 - val_accuracy: 0.8442 - val_recall_1: 0.8442
# Epoch 136/200
# 27/27 [==============================] - 17s 612ms/step - loss: 0.0456 - accuracy: 0.9817 - recall_1: 0.9817 - val_loss: 1.5218 - val_accuracy: 0.8514 - val_recall_1: 0.8478
# Epoch 137/200
# 27/27 [==============================] - 16s 610ms/step - loss: 0.0630 - accuracy: 0.9764 - recall_1: 0.9743 - val_loss: 1.5943 - val_accuracy: 0.8333 - val_recall_1: 0.8333
# Epoch 138/200
# 27/27 [==============================] - 17s 619ms/step - loss: 0.0742 - accuracy: 0.9696 - recall_1: 0.9681 - val_loss: 1.3857 - val_accuracy: 0.8696 - val_recall_1: 0.8696
# Epoch 139/200
# 27/27 [==============================] - 17s 623ms/step - loss: 0.0755 - accuracy: 0.9725 - recall_1: 0.9702 - val_loss: 1.4128 - val_accuracy: 0.8333 - val_recall_1: 0.8333
# Epoch 140/200
# 27/27 [==============================] - 17s 629ms/step - loss: 0.0442 - accuracy: 0.9849 - recall_1: 0.9849 - val_loss: 1.2801 - val_accuracy: 0.8732 - val_recall_1: 0.8732
# Epoch 141/200
# 27/27 [==============================] - 17s 613ms/step - loss: 0.0442 - accuracy: 0.9843 - recall_1: 0.9835 - val_loss: 1.5447 - val_accuracy: 0.8370 - val_recall_1: 0.8297
# Epoch 142/200
# 27/27 [==============================] - 17s 617ms/step - loss: 0.0436 - accuracy: 0.9858 - recall_1: 0.9846 - val_loss: 1.3637 - val_accuracy: 0.8732 - val_recall_1: 0.8732
# Epoch 143/200
# 27/27 [==============================] - 17s 613ms/step - loss: 0.0520 - accuracy: 0.9814 - recall_1: 0.9799 - val_loss: 1.5066 - val_accuracy: 0.8587 - val_recall_1: 0.8551
# Epoch 144/200
# 27/27 [==============================] - 17s 614ms/step - loss: 0.0519 - accuracy: 0.9802 - recall_1: 0.9790 - val_loss: 1.5191 - val_accuracy: 0.8587 - val_recall_1: 0.8587
# Epoch 145/200
# 27/27 [==============================] - 17s 616ms/step - loss: 0.0506 - accuracy: 0.9811 - recall_1: 0.9790 - val_loss: 1.4399 - val_accuracy: 0.8514 - val_recall_1: 0.8478
# Epoch 146/200
# 27/27 [==============================] - 17s 612ms/step - loss: 0.0534 - accuracy: 0.9764 - recall_1: 0.9758 - val_loss: 1.8303 - val_accuracy: 0.7790 - val_recall_1: 0.7790
# Epoch 147/200
# 27/27 [==============================] - 17s 616ms/step - loss: 0.0668 - accuracy: 0.9728 - recall_1: 0.9713 - val_loss: 1.2648 - val_accuracy: 0.8913 - val_recall_1: 0.8877
# Epoch 148/200
# 27/27 [==============================] - 17s 614ms/step - loss: 0.0423 - accuracy: 0.9837 - recall_1: 0.9826 - val_loss: 1.4404 - val_accuracy: 0.8514 - val_recall_1: 0.8514
# Epoch 149/200
# 27/27 [==============================] - 17s 616ms/step - loss: 0.0446 - accuracy: 0.9855 - recall_1: 0.9849 - val_loss: 1.4525 - val_accuracy: 0.8623 - val_recall_1: 0.8623
# Epoch 150/200
# 27/27 [==============================] - 17s 614ms/step - loss: 0.0406 - accuracy: 0.9867 - recall_1: 0.9852 - val_loss: 1.4172 - val_accuracy: 0.8587 - val_recall_1: 0.8587
# Epoch 151/200
# 27/27 [==============================] - 17s 614ms/step - loss: 0.0342 - accuracy: 0.9870 - recall_1: 0.9867 - val_loss: 1.6373 - val_accuracy: 0.8442 - val_recall_1: 0.8442
# Epoch 152/200
# 27/27 [==============================] - 17s 615ms/step - loss: 0.0358 - accuracy: 0.9885 - recall_1: 0.9876 - val_loss: 1.4589 - val_accuracy: 0.8514 - val_recall_1: 0.8514
# Epoch 153/200
# 27/27 [==============================] - 17s 612ms/step - loss: 0.0395 - accuracy: 0.9858 - recall_1: 0.9843 - val_loss: 1.7480 - val_accuracy: 0.8225 - val_recall_1: 0.8225
# Epoch 154/200
# 27/27 [==============================] - 17s 617ms/step - loss: 0.0414 - accuracy: 0.9840 - recall_1: 0.9835 - val_loss: 1.8263 - val_accuracy: 0.8333 - val_recall_1: 0.8333
# Epoch 155/200
# 27/27 [==============================] - 17s 613ms/step - loss: 0.0360 - accuracy: 0.9861 - recall_1: 0.9858 - val_loss: 1.6335 - val_accuracy: 0.8514 - val_recall_1: 0.8478
# Epoch 156/200
# 27/27 [==============================] - 17s 615ms/step - loss: 0.0291 - accuracy: 0.9888 - recall_1: 0.9879 - val_loss: 1.6391 - val_accuracy: 0.8370 - val_recall_1: 0.8370
# Epoch 157/200
# 27/27 [==============================] - 17s 613ms/step - loss: 0.0294 - accuracy: 0.9902 - recall_1: 0.9894 - val_loss: 1.6791 - val_accuracy: 0.8514 - val_recall_1: 0.8514
# Epoch 158/200
# 27/27 [==============================] - 17s 613ms/step - loss: 0.0301 - accuracy: 0.9902 - recall_1: 0.9897 - val_loss: 1.7048 - val_accuracy: 0.8370 - val_recall_1: 0.8370
# Epoch 159/200
# 27/27 [==============================] - 17s 612ms/step - loss: 0.0429 - accuracy: 0.9858 - recall_1: 0.9846 - val_loss: 1.8136 - val_accuracy: 0.8297 - val_recall_1: 0.8297
# Epoch 160/200
# 27/27 [==============================] - 17s 613ms/step - loss: 0.0495 - accuracy: 0.9829 - recall_1: 0.9823 - val_loss: 1.7802 - val_accuracy: 0.8152 - val_recall_1: 0.8152
# Epoch 161/200
# 27/27 [==============================] - 17s 613ms/step - loss: 0.0618 - accuracy: 0.9755 - recall_1: 0.9746 - val_loss: 1.4276 - val_accuracy: 0.8768 - val_recall_1: 0.8768
# Epoch 162/200
# 27/27 [==============================] - 17s 615ms/step - loss: 0.0492 - accuracy: 0.9826 - recall_1: 0.9820 - val_loss: 1.5960 - val_accuracy: 0.8659 - val_recall_1: 0.8623
# Epoch 163/200
# 27/27 [==============================] - 17s 615ms/step - loss: 0.0357 - accuracy: 0.9867 - recall_1: 0.9861 - val_loss: 1.4946 - val_accuracy: 0.8732 - val_recall_1: 0.8732
# Epoch 164/200
# 27/27 [==============================] - 17s 620ms/step - loss: 0.0364 - accuracy: 0.9882 - recall_1: 0.9879 - val_loss: 1.6216 - val_accuracy: 0.8768 - val_recall_1: 0.8768
# Epoch 165/200
# 27/27 [==============================] - 17s 614ms/step - loss: 0.0785 - accuracy: 0.9725 - recall_1: 0.9713 - val_loss: 1.6181 - val_accuracy: 0.8587 - val_recall_1: 0.8587
# Epoch 166/200
# 27/27 [==============================] - 17s 611ms/step - loss: 0.0688 - accuracy: 0.9790 - recall_1: 0.9775 - val_loss: 1.5355 - val_accuracy: 0.8659 - val_recall_1: 0.8659
# Epoch 167/200
# 27/27 [==============================] - 17s 613ms/step - loss: 0.0390 - accuracy: 0.9858 - recall_1: 0.9849 - val_loss: 1.5908 - val_accuracy: 0.8478 - val_recall_1: 0.8442
# Epoch 168/200
# 27/27 [==============================] - 17s 614ms/step - loss: 0.0292 - accuracy: 0.9911 - recall_1: 0.9905 - val_loss: 1.5772 - val_accuracy: 0.8551 - val_recall_1: 0.8551
# Epoch 169/200
# 27/27 [==============================] - 17s 611ms/step - loss: 0.0292 - accuracy: 0.9902 - recall_1: 0.9900 - val_loss: 1.5318 - val_accuracy: 0.8659 - val_recall_1: 0.8659
# Epoch 170/200
# 27/27 [==============================] - 17s 612ms/step - loss: 0.0392 - accuracy: 0.9858 - recall_1: 0.9855 - val_loss: 1.6155 - val_accuracy: 0.8514 - val_recall_1: 0.8514
# Epoch 171/200
# 27/27 [==============================] - 17s 649ms/step - loss: 0.0331 - accuracy: 0.9894 - recall_1: 0.9888 - val_loss: 1.4672 - val_accuracy: 0.8877 - val_recall_1: 0.8877
# Epoch 172/200
# 27/27 [==============================] - 19s 697ms/step - loss: 0.0470 - accuracy: 0.9826 - recall_1: 0.9820 - val_loss: 1.7621 - val_accuracy: 0.8261 - val_recall_1: 0.8225
# Epoch 173/200
# 27/27 [==============================] - 17s 641ms/step - loss: 0.0424 - accuracy: 0.9852 - recall_1: 0.9840 - val_loss: 1.7291 - val_accuracy: 0.8297 - val_recall_1: 0.8261
# Epoch 174/200
# 27/27 [==============================] - 17s 617ms/step - loss: 0.0488 - accuracy: 0.9790 - recall_1: 0.9790 - val_loss: 1.4763 - val_accuracy: 0.8623 - val_recall_1: 0.8623
# Epoch 175/200
# 27/27 [==============================] - 17s 633ms/step - loss: 0.0399 - accuracy: 0.9852 - recall_1: 0.9843 - val_loss: 1.6458 - val_accuracy: 0.8514 - val_recall_1: 0.8514
# Epoch 176/200
# 27/27 [==============================] - 17s 616ms/step - loss: 0.0346 - accuracy: 0.9876 - recall_1: 0.9873 - val_loss: 1.7287 - val_accuracy: 0.8333 - val_recall_1: 0.8333
# Epoch 177/200
# 27/27 [==============================] - 17s 612ms/step - loss: 0.0296 - accuracy: 0.9902 - recall_1: 0.9900 - val_loss: 1.6082 - val_accuracy: 0.8623 - val_recall_1: 0.8623
# Epoch 178/200
# 27/27 [==============================] - 17s 617ms/step - loss: 0.0339 - accuracy: 0.9864 - recall_1: 0.9858 - val_loss: 1.6052 - val_accuracy: 0.8406 - val_recall_1: 0.8406
# Epoch 179/200
# 27/27 [==============================] - 17s 613ms/step - loss: 0.0357 - accuracy: 0.9846 - recall_1: 0.9843 - val_loss: 1.6966 - val_accuracy: 0.8551 - val_recall_1: 0.8551
# Epoch 180/200
# 27/27 [==============================] - 17s 613ms/step - loss: 0.0384 - accuracy: 0.9852 - recall_1: 0.9843 - val_loss: 1.8485 - val_accuracy: 0.8333 - val_recall_1: 0.8297
# Epoch 181/200
# 27/27 [==============================] - 17s 619ms/step - loss: 0.0249 - accuracy: 0.9935 - recall_1: 0.9926 - val_loss: 1.6031 - val_accuracy: 0.8514 - val_recall_1: 0.8514
# Epoch 182/200
# 27/27 [==============================] - 17s 612ms/step - loss: 0.0316 - accuracy: 0.9885 - recall_1: 0.9882 - val_loss: 1.6693 - val_accuracy: 0.8478 - val_recall_1: 0.8478
# Epoch 183/200
# 27/27 [==============================] - 17s 615ms/step - loss: 0.0337 - accuracy: 0.9888 - recall_1: 0.9870 - val_loss: 2.0111 - val_accuracy: 0.8152 - val_recall_1: 0.8152
# Epoch 184/200
# 27/27 [==============================] - 17s 620ms/step - loss: 0.0242 - accuracy: 0.9917 - recall_1: 0.9911 - val_loss: 1.4793 - val_accuracy: 0.8877 - val_recall_1: 0.8877
# Epoch 185/200
# 27/27 [==============================] - 17s 620ms/step - loss: 0.0233 - accuracy: 0.9914 - recall_1: 0.9905 - val_loss: 1.6408 - val_accuracy: 0.8514 - val_recall_1: 0.8514
# Epoch 186/200
# 27/27 [==============================] - 17s 613ms/step - loss: 0.0299 - accuracy: 0.9900 - recall_1: 0.9885 - val_loss: 1.7093 - val_accuracy: 0.8587 - val_recall_1: 0.8587
# Epoch 187/200
# 27/27 [==============================] - 17s 615ms/step - loss: 0.0294 - accuracy: 0.9926 - recall_1: 0.9917 - val_loss: 1.7619 - val_accuracy: 0.8406 - val_recall_1: 0.8406
# Epoch 188/200
# 27/27 [==============================] - 17s 614ms/step - loss: 0.0280 - accuracy: 0.9902 - recall_1: 0.9897 - val_loss: 1.8020 - val_accuracy: 0.8442 - val_recall_1: 0.8442
# Epoch 189/200
# 27/27 [==============================] - 17s 611ms/step - loss: 0.0304 - accuracy: 0.9894 - recall_1: 0.9888 - val_loss: 2.1083 - val_accuracy: 0.8225 - val_recall_1: 0.8225
# Epoch 190/200
# 27/27 [==============================] - 17s 614ms/step - loss: 0.0202 - accuracy: 0.9959 - recall_1: 0.9950 - val_loss: 1.8076 - val_accuracy: 0.8696 - val_recall_1: 0.8696
# Epoch 191/200
# 27/27 [==============================] - 17s 613ms/step - loss: 0.0313 - accuracy: 0.9888 - recall_1: 0.9879 - val_loss: 2.4030 - val_accuracy: 0.8152 - val_recall_1: 0.8116
# Epoch 192/200
# 27/27 [==============================] - 17s 620ms/step - loss: 0.0335 - accuracy: 0.9885 - recall_1: 0.9879 - val_loss: 1.5939 - val_accuracy: 0.8804 - val_recall_1: 0.8804
# Epoch 193/200
# 27/27 [==============================] - 17s 614ms/step - loss: 0.0293 - accuracy: 0.9897 - recall_1: 0.9897 - val_loss: 2.1840 - val_accuracy: 0.8333 - val_recall_1: 0.8333
# Epoch 194/200
# 27/27 [==============================] - 17s 617ms/step - loss: 0.0255 - accuracy: 0.9917 - recall_1: 0.9911 - val_loss: 1.7973 - val_accuracy: 0.8587 - val_recall_1: 0.8587
# Epoch 195/200
# 27/27 [==============================] - 17s 621ms/step - loss: 0.0313 - accuracy: 0.9885 - recall_1: 0.9879 - val_loss: 1.5698 - val_accuracy: 0.8768 - val_recall_1: 0.8768
# Epoch 196/200
# 27/27 [==============================] - 17s 615ms/step - loss: 0.0302 - accuracy: 0.9908 - recall_1: 0.9905 - val_loss: 1.9589 - val_accuracy: 0.8225 - val_recall_1: 0.8225
# Epoch 197/200
# 27/27 [==============================] - 17s 613ms/step - loss: 0.0265 - accuracy: 0.9888 - recall_1: 0.9888 - val_loss: 2.1404 - val_accuracy: 0.8370 - val_recall_1: 0.8370
# Epoch 198/200
# 27/27 [==============================] - 17s 613ms/step - loss: 0.0290 - accuracy: 0.9885 - recall_1: 0.9885 - val_loss: 1.9931 - val_accuracy: 0.8659 - val_recall_1: 0.8659
# Epoch 199/200
# 27/27 [==============================] - 17s 617ms/step - loss: 0.0536 - accuracy: 0.9805 - recall_1: 0.9802 - val_loss: 1.7131 - val_accuracy: 0.8514 - val_recall_1: 0.8514
# Epoch 200/200
# 27/27 [==============================] - 17s 615ms/step - loss: 0.0583 - accuracy: 0.9775 - recall_1: 0.9764 - val_loss: 1.3557 - val_accuracy: 0.8949 - val_recall_1: 0.8913

# %%
# Evaluating the model on the training and testing set
train_loss, train_accuracy, train_recall = model.evaluate(X_train_smote, y_train_smote, verbose=1)
test_loss, test_accuracy, test_recall = model.evaluate(features_test_reshaped, labels_test_categorical, verbose=1)

print("Training:")
print("\tAccuracy:", train_accuracy)
print("\tRecall:", train_recall)


print("Testing:")
print("\tAccuracy:", test_accuracy)
print("\tRecall:", test_recall)
# Out:
# 106/106 [==============================] - 4s 36ms/step - loss: 0.1378 - accuracy: 0.9474 - recall_1: 0.9436
# 9/9 [==============================] - 0s 35ms/step - loss: 1.3557 - accuracy: 0.8949 - recall_1: 0.8913
# Training:
# 	Accuracy: 0.9473995566368103
# 	Recall: 0.9435579180717468
# Testing:
# 	Accuracy: 0.8949275612831116
# 	Recall: 0.8913043737411499

# %%
# Data for the bar chart
metrics = ['Accuracy', 'Recall']
train_values = [train_accuracy, train_recall]
test_values = [test_accuracy, test_recall]

x = np.arange(len(metrics))  # the label locations
width = 0.35  # the width of the bars

# Creating the bar chart
plt.figure(figsize=(10, 6))
train_bars = plt.bar(x - width/2, train_values, width, label='Train', color='blue', alpha=0.7)
test_bars = plt.bar(x + width/2, test_values, width, label='Test', color='green', alpha=0.7)

# Adding labels to the bars
def add_labels(bars):
    for bar in bars:
        yval = bar.get_height()
        plt.text(bar.get_x() + bar.get_width()/2, yval, round(yval, 2), va='bottom', ha='center')

add_labels(train_bars)
add_labels(test_bars)

plt.xlabel('Metrics')
plt.ylabel('Scores')
plt.title('Model Performance on Train vs Test Set')
plt.xticks(x, metrics)
plt.legend()
plt.show()

# %%
predictions = model.predict(features_test_reshaped)

predClass = np.argmax(predictions, axis=1)

realClass = np.argmax(labels_test_categorical, axis=1)
# Out:
# 9/9 [==============================] - 0s 33ms/step

# %%
# Compute ROC curve and ROC area for each class
fpr = {}
tpr = {}
roc_auc = {}
for i in range(len(unique_classes)):
    fpr[i], tpr[i], _ = roc_curve(labels_test_categorical[:, i], predictions[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# %%
c_names = ['Bronchiectasis', 'Bronchiolitis', 'COPD', 'Healthy', 'Pneumonia', 'URTI']

# %%
plt.figure(figsize = (8,6))

for i in range(len(c_names)):
    plt.plot(fpr[i], tpr[i], label=f'ROC curve (area = {roc_auc[i]:.2f}) for {c_names[i]}')
    
plt.plot([0, 1], [0, 1], 'k--')

plt.title('ROC')
plt.xlabel('FPR')
plt.ylabel('TPR')

plt.legend()
plt.grid()
plt.show()

# %%
print(classification_report(realClass, predClass, target_names=c_names))
# Out:
#                 precision    recall  f1-score   support
#
# Bronchiectasis       0.80      0.40      0.53        10
#  Bronchiolitis       0.25      0.14      0.18         7
#           COPD       0.99      0.97      0.98       229
#        Healthy       0.67      0.57      0.62        14
#      Pneumonia       0.50      1.00      0.67         9
#           URTI       0.25      0.43      0.32         7
#
#       accuracy                           0.89       276
#      macro avg       0.58      0.59      0.55       276
#   weighted avg       0.91      0.89      0.90       276
